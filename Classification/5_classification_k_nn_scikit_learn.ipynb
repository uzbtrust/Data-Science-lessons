# %%
import pandas as pd
import numpy as np

# %%
url="https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/breast-cancer.csv"
df = pd.read_csv(url)
df.sample(10)
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 566    926954         M       16.600         28.08          108.30      858.1
# 27     852781         M       18.610         20.25          122.10     1094.0
# 185    874158         B       10.080         15.11           63.76      317.5
# 534    919537         B       10.960         17.62           70.79      365.6
# 318    894329         B        9.042         18.90           60.07      244.5
# 285   8912521         B       12.580         18.40           79.83      489.0
# 57     857793         M       14.710         21.59           95.55      656.9
# 178    873357         B       13.010         22.22           82.01      526.4
# 397  90401602         B       12.800         17.46           83.05      508.3
# 491  91376702         B       17.850         13.23          114.60      992.1
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 566          0.08455           0.10230        0.092510             0.053020
# 27           0.09440           0.10660        0.149000             0.077310
# 185          0.09267           0.04695        0.001597             0.002404
# 534          0.09687           0.09752        0.052630             0.027880
# 318          0.09968           0.19720        0.197500             0.049080
# 285          0.08393           0.04216        0.001860             0.002924
# 57           0.11370           0.13650        0.129300             0.081230
# 178          0.06251           0.01938        0.001595             0.001852
# 397          0.08044           0.08895        0.073900             0.040830
# 491          0.07838           0.06217        0.044450             0.041780
#
#      ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 566  ...         18.98          34.12           126.70      1124.0
# 27   ...         21.31          27.26           139.90      1403.0
# 185  ...         11.87          21.18            75.39       437.0
# 534  ...         11.62          26.51            76.43       407.5
# 318  ...         10.06          23.40            68.62       297.1
# 285  ...         13.50          23.08            85.56       564.1
# 57   ...         17.87          30.70           115.70       985.5
# 178  ...         14.00          29.02            88.18       608.8
# 397  ...         13.74          21.06            90.72       591.0
# 491  ...         19.82          18.42           127.10      1210.0
#
#      smoothness_worst  compactness_worst  concavity_worst  \
# 566           0.11390            0.30940         0.340300
# 27            0.13380            0.21170         0.344600
# 185           0.15210            0.10190         0.006920
# 534           0.14280            0.25100         0.212300
# 318           0.12210            0.37480         0.460900
# 285           0.10380            0.06624         0.005579
# 57            0.13680            0.42900         0.358700
# 178           0.08125            0.03432         0.007977
# 397           0.09534            0.18120         0.190100
# 491           0.09862            0.09976         0.104800
#
#      concave points_worst  symmetry_worst  fractal_dimension_worst
# 566              0.141800          0.2218                  0.07820
# 27               0.149000          0.2341                  0.07421
# 185              0.010420          0.2933                  0.07697
# 534              0.098610          0.2289                  0.08278
# 318              0.114500          0.3135                  0.10550
# 285              0.008772          0.2505                  0.06431
# 57               0.183400          0.3698                  0.10940
# 178              0.009259          0.2295                  0.05843
# 397              0.082960          0.1988                  0.07053
# 491              0.083410          0.1783                  0.05871
#
# [10 rows x 32 columns]

# %%
df.shape
# Out:
# (569, 32)

# %% [markdown]
# Dataset ko'krakdagi o'simta haqida ma'lumotlarni jamlagan. `diagnosis` ustuni esa o'simta rak (M - malignant) yoki rak emas (B - benign) anglatadi.

# %%
df['diagnosis'].value_counts()
# Out:
# diagnosis
# B    357
# M    212
# Name: count, dtype: int64

# %% [markdown]
# Keling bu qiymatlarni 0 va 1 ga o'zgartiramiz. M->1, B->0
#
# Buning uchun yoki `sklearn` tarkibidagi `LabelEncoder` dan yoki `pandas` dagi `.replace()` metodidan foydalanish mumkin. Biz ikkisini ham qoldiramiz.

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()

df['diagnosis'] = labelencoder.fit_transform(df['diagnosis'].values)
df['diagnosis'].value_counts()
# Out:
# diagnosis
# 0    357
# 1    212
# Name: count, dtype: int64

# %%
# df['diagnosis'] = df['diagnosis'].replace("M",1)
# df['diagnosis'] = df['diagnosis'].replace("B",0)
# df['diagnosis'].value_counts()

# %% [markdown]
# ID ustunini tashlab yuboramiz

# %%
df.drop(columns=['id'], inplace=True)

# %%
corr_matrix = df.corr().abs()
corr_matrix.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_b7619_row0_col0, #T_b7619_row1_col1, #T_b7619_row1_col3, #T_b7619_row2_col2, #T_b7619_row3_col1, #T_b7619_row3_col3, #T_b7619_row4_col4, #T_b7619_row5_col5, #T_b7619_row6_col6, #T_b7619_row7_col7, #T_b7619_row8_col8, #T_b7619_row9_col9, #T_b7619_row10_col10, #T_b7619_row11_col11, #T_b7619_row12_col12, #T_b7619_row13_col13, #T_b7619_row14_col14, #T_b7619_row15_col15, #T_b7619_row16_col16, #T_b7619_row17_col17, #T_b7619_row18_col18, #T_b7619_row19_col19, #T_b7619_row20_col20, #T_b7619_row21_col21, #T_b7619_row22_col22, #T_b7619_row23_col23, #T_b7619_row24_col24, #T_b7619_row25_col25, #T_b7619_row26_col26, #T_b7619_row27_col27, #T_b7619_row28_col28, #T_b7619_row29_col29, #T_b7619_row30_col30 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_b7619_row0_col1, #T_b7619_row0_col24, #T_b7619_row1_col0, #T_b7619_row7_col23, #T_b7619_row17_col20 {
#   background-color: #f6a283;
#   color: #000000;
# }
# #T_b7619_row0_col2, #T_b7619_row0_col25, #T_b7619_row2_col0, #T_b7619_row5_col27, #T_b7619_row9_col27, #T_b7619_row9_col28, #T_b7619_row29_col0 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_b7619_row0_col3, #T_b7619_row3_col0, #T_b7619_row3_col14, #T_b7619_row7_col26, #T_b7619_row24_col28, #T_b7619_row28_col24 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_b7619_row0_col4, #T_b7619_row4_col0, #T_b7619_row23_col7, #T_b7619_row23_col13 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# #T_b7619_row0_col5, #T_b7619_row10_col19, #T_b7619_row18_col10, #T_b7619_row19_col29, #T_b7619_row24_col22 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_b7619_row0_col6, #T_b7619_row10_col5 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_b7619_row0_col7, #T_b7619_row7_col24, #T_b7619_row13_col1 {
#   background-color: #f7b79b;
#   color: #000000;
# }
# #T_b7619_row0_col8, #T_b7619_row20_col16, #T_b7619_row28_col3 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_b7619_row0_col9, #T_b7619_row2_col8, #T_b7619_row10_col4, #T_b7619_row10_col18, #T_b7619_row10_col29, #T_b7619_row12_col20, #T_b7619_row13_col5, #T_b7619_row20_col9, #T_b7619_row24_col18 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_b7619_row0_col10, #T_b7619_row8_col12, #T_b7619_row14_col30, #T_b7619_row22_col5 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_b7619_row0_col11, #T_b7619_row0_col26 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_b7619_row0_col12, #T_b7619_row0_col19, #T_b7619_row1_col30, #T_b7619_row2_col5, #T_b7619_row2_col9, #T_b7619_row2_col15, #T_b7619_row2_col19, #T_b7619_row4_col30, #T_b7619_row10_col11, #T_b7619_row10_col13, #T_b7619_row11_col10, #T_b7619_row12_col0, #T_b7619_row12_col6, #T_b7619_row12_col7, #T_b7619_row12_col8, #T_b7619_row14_col29, #T_b7619_row15_col2, #T_b7619_row15_col26, #T_b7619_row19_col0, #T_b7619_row19_col2, #T_b7619_row19_col25, #T_b7619_row19_col27, #T_b7619_row19_col28, #T_b7619_row20_col3, #T_b7619_row20_col21, #T_b7619_row20_col22, #T_b7619_row20_col23, #T_b7619_row20_col24, #T_b7619_row22_col16, #T_b7619_row22_col17, #T_b7619_row22_col18, #T_b7619_row22_col20, #T_b7619_row23_col20, #T_b7619_row30_col1, #T_b7619_row30_col4, #T_b7619_row30_col14 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_
{
#   background-color: #f5a081;
#   color: #000000;
# }
# #T_b7619_row1_col15, #T_b7619_row9_col23, #T_b7619_row13_col12, #T_b7619_row15_col1, #T_b7619_row15_col23, #T_b7619_row16_col25, #T_b7619_row22_col25, #T_b7619_row22_col30, #T_b7619_row30_col22 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_b7619_row1_col16, #T_b7619_row10_col14, #T_b7619_row15_col22, #T_b7619_row15_col28, #T_b7619_row20_col0, #T_b7619_row21_col16, #T_b7619_row22_col19, #T_b7619_row25_col2, #T_b7619_row29_col13, #T_b7619_row30_col19 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_b7619_row1_col17, #T_b7619_row12_col16, #T_b7619_row12_col17, #T_b7619_row14_col12, #T_b7619_row19_col23, #T_b7619_row21_col12, #T_b7619_row24_col19 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_b7619_row1_col19, #T_b7619_row12_col23, #T_b7619_row15_col30, #T_b7619_row19_col1, #T_b7619_row23_col19, #T_b7619_row24_col17, #T_b7619_row25_col16, #T_b7619_row29_col2, #T_b7619_row29_col15 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_b7619_row1_col20, #T_b7619_row12_col30, #T_b7619_row13_col10, #T_b7619_row20_col29 {
#   background-color

# %%
df.corrwith(df['diagnosis']).abs().sort_values(ascending=False)
# Out:
# diagnosis                  1.000000
# concave points_worst       0.793566
# perimeter_worst            0.782914
# concave points_mean        0.776614
# radius_worst               0.776454
# perimeter_mean             0.742636
# area_worst                 0.733825
# radius_mean                0.730029
# area_mean                  0.708984
# concavity_mean             0.696360
# concavity_worst            0.659610
# compactness_mean           0.596534
# compactness_worst          0.590998
# radius_se                  0.567134
# perimeter_se               0.556141
# area_se                    0.548236
# texture_worst              0.456903
# smoothness_worst           0.421465
# symmetry_worst             0.416294
# texture_mean               0.415185
# concave points_se          0.408042
# smoothness_mean            0.358560
# symmetry_mean              0.330499
# fractal_dimension_worst    0.323872
# compactness_se             0.292999
# concavity_se               0.253730
# fractal_dimension_se       0.077972
# smoothness_se              0.067016
# fractal_dimension_mean     0.012838
# texture_se                 0.008303
# symmetry_se                0.006522
# dtype: float64

# %% [markdown]
# ### ML ga tayyorlaymiz

# %%
X = df.drop('diagnosis', axis=1).values
y = df['diagnosis']

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X = scaler.fit_transform(X)

# %% [markdown]
# ## ML

# %%
# Train/test split
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=12)

# k-NN
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=5) # k-ni qiymati

knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_predict = knn.predict(X_test)

# %% [markdown]
# ## Baholash

# %% [markdown]
# ### Jaccard index

# %%
from sklearn.metrics import jaccard_score

jaccard_score(y_test, y_predict)
# Out:
# np.float64(0.8958333333333334)

# %% [markdown]
# ### Confusion matrix

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(confusion_matrix(y_test, y_predict), annot=True)
plt.show()

# %%
confusion_matrix(y_test, y_predict)
# Out:
# array([[66,  0],
#        [ 5, 43]])

# %% [markdown]
# ### Precision, recall, F1

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
precision = precision_score(y_test, y_predict)
recall = recall_score(y_test, y_predict)
f1 = f1_score(y_test, y_predict)
accuracy = accuracy_score(y_test, y_predict)
print(f"{precision=}\n{recall=}\n{f1=}\n{accuracy=}")
# Out:
# precision=1.0
# recall=0.8958333333333334
# f1=0.945054945054945
# accuracy=0.956140350877193

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96        66
#            1       1.00      0.90      0.95        48
#
#     accuracy                           0.96       114
#    macro avg       0.96      0.95      0.95       114
# weighted avg       0.96      0.96      0.96       114

# %% [markdown]
# ### Cross-validation yordamida tekshiramiz

# %%
# Cross validation
from sklearn.model_selection import cross_val_predict
predict = cross_val_predict(estimator = knn, X = X, y = y, cv = 5)

# Modelni baholash
from sklearn.metrics import classification_report
print("Classification Report: \n",classification_report(y, predict))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97       357
#            1       0.97      0.93      0.95       212
#
#     accuracy                           0.96       569
#    macro avg       0.97      0.96      0.96       569
# weighted avg       0.96      0.96      0.96       569
