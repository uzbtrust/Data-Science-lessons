# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Ma'lumotlar normalizatsiya qilinishi kerak

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# k-value Elbow Method orqali topiladi

# %% [markdown]
# ![image.png](data:image/png;base64,...)
