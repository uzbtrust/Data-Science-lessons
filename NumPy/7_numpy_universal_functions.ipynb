# %%
import numpy as np

# %%
arr = np.sqrt(4)
arr
# Out:
# np.float64(2.0)

# %%
arr = np.square(2)
arr
# Out:
# np.int64(4)

# %%
arr1 = np.random.rand(5)
arr1
# Out:
# array([0.88441287, 0.2179406 , 0.8195227 , 0.26504877, 0.82360349])

# %%
np.exp(arr1)
# Out:
# array([1.53708663, 1.87552016, 1.46535077, 2.11703422, 1.35218299])

# %%
np.log(arr1)
# Out:
# array([-0.84422864, -0.46380521, -0.96208694, -0.28766053, -1.19825479])

# %%
np.sign(arr1)
# Out:
# array([1., 1., 1., 1., 1.])

# %%
arr2,arr3 = np.modf(arr1)
print(arr2)
print(arr3)
# Out:
# [0.88441287 0.2179406  0.8195227  0.26504877 0.82360349]
# [0. 0. 0. 0. 0.]

# %%
np.add(arr2,arr3)
# Out:
# array([0.88441287, 0.2179406 , 0.8195227 , 0.26504877, 0.82360349])

# %%
arr1[0] = np.nan
arr1
# Out:
# array([       nan, 0.2179406 , 0.8195227 , 0.26504877, 0.82360349])

# %%
np.isnan(arr1)
# Out:
# array([ True, False, False, False, False])

# %%
np.multiply(arr2,arr3)
# Out:
# array([0., 0., 0., 0., 0.])

# %%
np.maximum(arr2,arr2)
# Out:
# array([0.88441287, 0.2179406 , 0.8195227 , 0.26504877, 0.82360349])
