# %%
import numpy as np

# %%
arr1 = np.array([1,2,3], dtype=np.float64)
arr1
# Out:
# array([1., 2., 3.])

# %%
arr2 = np.array([1,2,3], dtype=np.int32)
arr2
# Out:
# array([1, 2, 3], dtype=int32)

# %%
arr2.dtype
# Out:
# dtype('int32')

# %%
arr = np.array([1,2,3])
arr.dtype
# Out:
# dtype('int64')

# %%
float_arr = arr.astype(np.float64)
float_arr.dtype
# Out:
# dtype('float64')

# %%
data = np.array([1,2.5,4.3,5])
new_data = data.astype(np.int32)
new_data
# Out:
# array([1, 2, 4, 5], dtype=int32)

# %%
import numpy as np
