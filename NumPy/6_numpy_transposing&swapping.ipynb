# %%
import numpy as np

# %%
arr = np.arange(6).reshape(3,2)
arr
# Out:
# array([[0, 1],
#        [2, 3],
#        [4, 5]])

# %%
arr_t = arr.T
arr_t
# Out:
# array([[0, 2, 4],
#        [1, 3, 5]])

# %%
arr_s = arr.swapaxes(1,0)
arr_s
# Out:
# array([[0, 2, 4],
#        [1, 3, 5]])

# %%
np.dot(arr, arr.T)
# Out:
# array([[ 1,  3,  5],
#        [ 3, 13, 23],
#        [ 5, 23, 41]])
