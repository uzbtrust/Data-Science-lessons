# %%
import numpy as np

# %%
names = np.array(['Bob', 'Joe', 'Will', 'Bob', 'Will', 'Joe', 'Joe'])
ints = np.array([3, 3, 3, 2, 2, 1, 1, 4, 4])

# %%
np.unique(names)
# Out:
# array(['Bob', 'Joe', 'Will'], dtype='<U4')

# %%
np.unique(ints)
# Out:
# array([1, 2, 3, 4])

# %%
np.isin(names, "Bob")
# Out:
# array([ True, False, False,  True, False, False, False])

# %%
np.setdiff1d(names, "Bob")
# Out:
# array(['Joe', 'Will'], dtype='<U4')
