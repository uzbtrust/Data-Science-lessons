# %%
import numpy as np

# %%
names = np.array(['Hasan', 'Husan', 'Alisher', 'Yusuf'])
names
# Out:
# array(['Hasan', 'Husan', 'Alisher', 'Yusuf'], dtype='<U7')

# %%
data = np.random.randn(4,4)
data
# Out:
# array([[-0.33328438, -1.09507388, -0.90694232,  0.08894029],
#        [ 0.8164599 ,  0.35150166,  0.30435051,  0.26515727],
#        [-0.62489988,  0.99212868, -0.31383932, -0.42613302],
#        [ 0.35915322, -1.16013211, -1.47755858,  0.24038601]])

# %%
names == 'Hasan'
# Out:
# array([ True, False, False, False])

# %%
data[names == 'Hasan']
# Out:
# array([[-0.33328438, -1.09507388, -0.90694232,  0.08894029]])

# %%
data[names == 'Hasan', 1:]
# Out:
# array([[-1.09507388, -0.90694232,  0.08894029]])

# %%
data[names != 'Hasan']
# Out:
# array([[ 0.8164599 ,  0.35150166,  0.30435051,  0.26515727],
#        [-0.62489988,  0.99212868, -0.31383932, -0.42613302],
#        [ 0.35915322, -1.16013211, -1.47755858,  0.24038601]])

# %%
data[names != 'Hasan',2:]
# Out:
# array([[ 0.30435051,  0.26515727],
#        [-0.31383932, -0.42613302],
#        [-1.47755858,  0.24038601]])

# %%
mask = (names == 'Hasan') | (names == 'Husan')
mask
# Out:
# array([ True,  True, False, False])

# %%
data[mask]
# Out:
# array([[-0.33328438, -1.09507388, -0.90694232,  0.08894029],
#        [ 0.8164599 ,  0.35150166,  0.30435051,  0.26515727]])

# %%
data[data<0]=0
data
# Out:
# array([[0.        , 0.        , 0.        , 0.08894029],
#        [0.8164599 , 0.35150166, 0.30435051, 0.26515727],
#        [0.        , 0.99212868, 0.        , 0.        ],
#        [0.35915322, 0.        , 0.        , 0.24038601]])
