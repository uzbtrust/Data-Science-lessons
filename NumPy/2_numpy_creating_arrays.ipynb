# %%
import numpy as np

# %%
data1 = [3.5, 5, -3, 2]
arr1 = np.array(data1)
arr1
# Out:
# array([ 3.5,  5. , -3. ,  2. ])

# %%
data2 = (4,6,8,-8)
arr2 = np.array(data2)
arr2
# Out:
# array([ 4,  6,  8, -8])

# %%
data3 = [[1,2,3],[4,5,6]]
arr3 = np.array(data3)
arr3
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
arr3.ndim
# Out:
# 2

# %% [markdown]
# arr_name.shape - arr_name - arr_name arrayining qator va ustunlar sonini beradi
#
# arr_name.size - arr_name arrayi ichidagi ma'lumotlar soni

# %%
arr3.shape
# Out:
# (2, 3)

# %%
arr3.size
# Out:
# 6

# %% [markdown]
# arr = np.zeros(shape = (2, 4)) - faqat 0 dan iborat massiv yaratadi, shape yozish majburiy
#
# arr = np.ones(shape = (2, 4)) - faqat 1 dan iborat massiv yaratadi, shape yozish majburiy

# %%
zero_arr = np.zeros(shape=(2,4))
zero_arr
# Out:
# array([[0., 0., 0., 0.],
#        [0., 0., 0., 0.]])

# %%
one_arr = np.ones(shape = (2,4))
one_arr
# Out:
# array([[1., 1., 1., 1.],
#        [1., 1., 1., 1.]])

# %% [markdown]
# arr = np.arange(1,10,2) - pythondagi range funksiyasi bilan bir hil

# %%
r_arr = np.arange(1,100,4)
r_arr
# Out:
# array([ 1,  5,  9, 13, 17, 21, 25, 29, 33, 37, 41, 45, 49, 53, 57, 61, 65,
#        69, 73, 77, 81, 85, 89, 93, 97])
