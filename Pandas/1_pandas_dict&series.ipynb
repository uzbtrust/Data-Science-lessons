# %%
import pandas as pd
from pandas import Series
import numpy as np

# %%
cars_dict = {
    "Malibu" : 45000,
    "Onix" : 20000,
    "Cobalt": 10000,
    "Gentra": 15000,
    "Damas": 8000
}
car_series = Series(cars_dict)
car_series
# Out:
# Malibu    45000
# Onix      20000
# Cobalt    10000
# Gentra    15000
# Damas      8000
# dtype: int64

# %%
"Malibu" in car_series
# Out:
# True

# %%
"Spark" in car_series
# Out:
# False

# %%
car_series['Onix']
# Out:
# np.int64(20000)

# %%
models = ["Malibu", "Onix", "Cobalt", "Lacetti", "Gentra", "Damas"]
models
# Out:
# ['Malibu', 'Onix', 'Cobalt', 'Lacetti', 'Gentra', 'Damas']

# %%
cars2 = Series(cars_dict, index=models)
cars2
# Out:
# Malibu     45000.0
# Onix       20000.0
# Cobalt     10000.0
# Lacetti        NaN
# Gentra     15000.0
# Damas       8000.0
# dtype: float64
