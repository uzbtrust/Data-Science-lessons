# %%
import pandas as pd
from pandas import DataFrame

# %%
data = {
    "O'zbekiston": {2021:33.9, 2020:33.5, 2019:33.0, 2018:32.4, 2017:36.5},
    "Kazakhstan": {2021:18.9, 2020:18.7, 2019:18.5, 2018:18.3, 2017:18.1, 2016:17.8}
}
df = pd.DataFrame(data)
df
# Out:
#       O'zbekiston  Kazakhstan
# 2021         33.9        18.9
# 2020         33.5        18.7
# 2019         33.0        18.5
# 2018         32.4        18.3
# 2017         36.5        18.1
# 2016          NaN        17.8

# %%
indeks = df.columns
indeks
# Out:
# Index(['O'zbekiston', 'Kazakhstan'], dtype='object')

# %%
"O'zbekiston" in indeks
# Out:
# True

# %%
2020 in df.index
# Out:
# True

# %%
df.index.name = "Yil"

# %%
indeks[0]
# Out:
# "O'zbekiston"
