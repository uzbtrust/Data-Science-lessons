# %%
import pandas as pd
from pandas import DataFrame

# %%
usernames = {"anvar": "anvarbek223", "olim": "olimtoy", "maryam":"maryam334455", "javohir":"javohir445"}
emails = {"anvar": "anvar@gmail.com", "olim":"olim@mail.ru", "maryam": "mary33@gmail.com", "javohir": "javohir445@gmail.com"}
data ={
    'username': usernames,
    'email': emails
}
df = DataFrame(data)
df
# Out:
#              username                 email
# anvar     anvarbek223       anvar@gmail.com
# olim          olimtoy          olim@mail.ru
# maryam   maryam334455      mary33@gmail.com
# javohir    javohir445  javohir445@gmail.com

# %%
df.index
# Out:
# Index(['anvar', 'olim', 'maryam', 'javohir'], dtype='object')

# %%
arr = ['anvar', 'olim', 'maryam', 'javohir']
arr[0]
# Out:
# 'anvar'

# %%
arr[1]
# Out:
# 'olim'

# %%
data2 = {
    'username':{'olim':'olimjon','maryam':'maryam2020'},
    'email':{'olim':'olimjon2021@mail.ru', 'maryam':'maryam20@gmail.com'}
}
df2 = pd.concat([df, pd.DataFrame(data2)])
df2
# Out:
#              username                 email
# anvar     anvarbek223       anvar@gmail.com
# olim          olimtoy          olim@mail.ru
# maryam   maryam334455      mary33@gmail.com
# javohir    javohir445  javohir445@gmail.com
# olim          olimjon   olimjon2021@mail.ru
# maryam     maryam2020    maryam20@gmail.com

# %%
newid = pd.Index(['olim', 'husan', 'hasan'])
newid
# Out:
# Index(['olim', 'husan', 'hasan'], dtype='object')

# %%
newid.isin(df2.index)
# Out:
# array([ True, False, False])

# %%
newid.difference(df.index)
# Out:
# Index(['hasan', 'husan'], dtype='object')

# %%
df2.index.union(newid)
# Out:
# Index(['anvar', 'hasan', 'husan', 'javohir', 'maryam', 'maryam', 'olim',
#        'olim'],
#       dtype='object')

# %%
df2.index.delete(0)
# Out:
# Index(['olim', 'maryam', 'javohir', 'olim', 'maryam'], dtype='object')

# %%
newid.drop('husan')
# Out:
# Index(['olim', 'hasan'], dtype='object')

# %%
df2.index.insert(0, 'husan')
# Out:
# Index(['husan', 'anvar', 'olim', 'maryam', 'javohir', 'olim', 'maryam'], dtype='object')

# %%
df2.index.is_unique
# Out:
# False

# %%
df2.index.unique()
# Out:
# Index(['anvar', 'olim', 'maryam', 'javohir'], dtype='object')
