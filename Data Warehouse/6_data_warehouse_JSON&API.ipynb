# %%
import pandas as pd
import numpy as np

# %%
# !git clone "https://github.com/anvarnarz/praktikum_datasets"
# Out:
# Cloning into 'praktikum_datasets'...
# remote: Enumerating objects: 145, done.
# remote: Counting objects: 100% (52/52), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 145 (delta 46), reused 44 (delta 43), pack-reused 93 (from 1)
# Receiving objects: 100% (145/145), 9.72 MiB | 13.40 MiB/s, done.
# Resolving deltas: 100% (53/53), done.

# %%
# !wget -O universities_ranking.json "https://storage.googleapis.com/kagglesdsdata/datasets/996631/1682217/universities_ranking.json?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20250414%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20250414T090900Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=..."
# Out:
# --2025-04-14 09:28:26--  https://storage.googleapis.com/kagglesdsdata/datasets/996631/1682217/universities_ranking.json?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20250414%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20250414T090900Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=...
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.141.207, 74.125.137.207, 142.250.101.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.141.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 393811 (385K) [application/json]
# Saving to: ‘universities_ranking.json’
#
# universities_rankin 100%[===================>] 384.58K  1.34MB/s    in 0.3s
#
# 2025-04-14 09:28:27 (1.34 MB/s) - ‘universities_ranking.json’ saved [393811/393811]

# %%
pd.read_json("universities_ranking.json")
# Out:
#       ranking                                           title        location  \
# 0           1                            University of Oxford  United Kingdom
# 1           2                             Stanford University   United States
# 2           3                              Harvard University   United States
# 3           4              California Institute of Technology   United States
# 4           5           Massachusetts Institute of Technology   United States
# ...       ...                                             ...             ...
# 1521     1522                              Yuan Ze University          Taiwan
# 1522     1523  Yuriy Fedkovych Chernivtsi National University         Ukraine
# 1523     1524                              Zagazig University           Egypt
# 1524     1525                            University of Zagreb         Croatia
# 1525     1526                            University of Žilina        Slovakia
#
# ...

# %%
import requests
r = requests.get("https://openlibrary.org/subjects/python.json?published_in=2010-2025")
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# {'key': '/subjects/python',
#  'name': 'python',
#  'subject_type': 'subject',
#  'work_count': 114,
#  'works': [{'key': '/works/OL2784125W',
#    'title': 'Learning Python',
#    'edition_count': 22,
#    'cover_id': 1312568,
#    'cover_edition_key': 'OL9497269M',
#    'subject': ['Python (Langage de programmation)',
#     'Python (linguagem de programação)',
#     'Python (Computer program language)',
#     'Python (Lenguaje de programación de computadores)',
#     'Langage à objets',
#     'Python (programmeertaal)',
#     'Object-oriented programming (Computer science)',
#     'Python (Computer language)',
#     'Interpréteur',
#     'Python',
#     'COMPUTERS',
#     'Programming Languages',
#     'Engineering & Applied Sciences',
#     'Computer Science',
#     'General',
#     'Reference',
#     'Games',
#     'Com051360',
#     'Cs.cmp_sc.app_sw',
#     'Cs.cmp_sc.prog_lang',
#     'Professional, career & trade -> computer science -> programming languages (jr/sr)',
# ...

# %%
pd.DataFrame(r.json()['works'])
# Out:
#                    key                                              title  \
# 0    /works/OL2784125W                                    Learning Python
# 1    /works/OL2784127W                                             Python
# 2   /works/OL16976951W                                       Think Python
# 3   /works/OL17795703W                          Python for bioinformatics
# 4   /works/OL21349037W  Introduction to Python for Science and Enginee...
# 5    /works/OL2784126W                                 Programming Python
# 6   /works/OL15667639W                              Mining the Social Web
# 7   /works/OL15664278W                                  Head First Python
# 8    /works/OL6045694W                               Python in a Nutshell
# 9   /works/OL17422847W                           Python For Data Analysis
# 10  /works/OL16223034W                                        Think Stats
# 11  /works/OL23330617W                        Making music with computers
#
# ...
