# %%
import pandas as pd
import numpy as np

# %%
# !git clone "https://github.com/anvarnarz/praktikum_datasets"
# Out:
# Cloning into 'praktikum_datasets'...
# remote: Enumerating objects: 145, done.
# remote: Counting objects: 100% (52/52), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 145 (delta 46), reused 44 (delta 43), pack-reused 93 (from 1)
# Receiving objects: 100% (145/145), 9.72 MiB | 11.21 MiB/s, done.
# Resolving deltas: 100% (53/53), done.

# %%
df = pd.read_excel('praktikum_datasets/uzbekistan.xlsx')
df.head()
# Out:
#           Boʻlinishi  Maydoni (kv.km)  Aholisi
# 0   Andijon viloyati             4200  1899000
# 1    Buxoro viloyati            39400  1384700
# 2  Fargʻona viloyati             6800  2597000
# 3    Jizzax viloyati            20500   910500
# 4    Xorazm viloyati             6300  1200000

# %%
df2 = pd.read_csv('praktikum_datasets/automobile_data.csv')
df2.head()
# Out:
#    index      company   body-style  wheel-base  length engine-type  \
# 0      0  alfa-romero  convertible        88.6   168.8        dohc
# 1      1  alfa-romero  convertible        88.6   168.8        dohc
# 2      2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3      3         audi        sedan        99.8   176.6         ohc
# 4      4         audi        sedan        99.4   176.6         ohc
#
#   num-of-cylinders  horsepower  average-mileage    price
# 0             four         111               21  13495.0
# 1             four         111               21  16500.0
# 2              six         154               19  16500.0
# 3             four         102               24  13950.0
# 4             five         115               18  17450.0

# %%
hdfobj = pd.HDFStore('data.h5')

# %%
hdfobj.put('uz_data', df)

# %%
hdfobj.put('auto_data', df2)

# %%
hdfobj.keys()
# Out:
# ['/auto_data', '/uz_data']

# %%
hdfobj['uz_data'].head()
# Out:
#           Boʻlinishi  Maydoni (kv.km)  Aholisi
# 0   Andijon viloyati             4200  1899000
# 1    Buxoro viloyati            39400  1384700
# 2  Fargʻona viloyati             6800  2597000
# 3    Jizzax viloyati            20500   910500
# 4    Xorazm viloyati             6300  1200000

# %%
hdfobj.close()

# %%
hdfobj['uz_data'].head()
# Out:
# ---------------------------------------------------------------------------
# ClosedFileError                           Traceback (most recent call last)
# <ipython-input-11-3b35fb095193> in <cell line: 0>()
# ----> 1 hdfobj['uz_data'].head()
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/pytables.py in __getitem__(self, key)
#     600
#     601     def __getitem__(self, key: str):
# --> 602         return self.get(key)
#     603
#     604     def __setitem__(self, key: str, value) -> None:
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/pytables.py in get(self, key)
#     808             # GH#31167 Without this patch, pickle doesn't know how to unpickle
#     809             #  old DateOffset objects now that they are cdef classes.
# --> 810             group = self.get_node(key)
#     811             if group is None:
#     812                 raise KeyError(f"No object named {key} in the file")
#
# ...

# %%
hdfobj = pd.HDFStore('data.h5')

# %%
hdfobj.close()

# %%
data = pd.read_hdf('data.h5', key='uz_data')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-36383ae5a3ff> in <cell line: 0>()
# ----> 1 data = pd.read_hdf('data.h5', key='uz_data')
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/pytables.py in read_hdf(path_or_buf, key, mode, errors, where, start, stop, columns, iterator, chunksize, **kwargs)
#     424             raise FileNotFoundError(f"File {path_or_buf} does not exist")
#     425
# --> 426         store = HDFStore(path_or_buf, mode=mode, errors=errors, **kwargs)
#     427         # can't auto open/close if we are using an iterator
#     428         # so delegate to the iterator
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/pytables.py in __init__(self, path, mode, complevel, complib, fletcher32, **kwargs)
#     583         self._fletcher32 = fletcher32
#     584         self._filters = None
# ...

# %%
data.to_hdf('data.h5', key='uz_data')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-a3ec51988146> in <cell line: 0>()
# ----> 1 data.to_hdf('data.h5', key='uz_data')
#
# NameError: name 'data' is not defined
