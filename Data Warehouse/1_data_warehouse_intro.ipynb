# %%
import pandas as pd
import numpy as np

# %% [markdown]
# pandas bilan filelarni o'qish
#
# pd.read_csv() - vergul bilan ajratilgan fileni o'qish
#
# pd.read_table() - bo'sh joy bilan ajratilgan fileni o'qish
#
# pd.read_excel() - excel fileni o'qish
#
# pd.read_clipboard() - ko'chirilgan(xotiradagi) jadvalni o'qish
#
# pd.read_hdf() - HDF5 filelarni o'qish
#
# pd.read_html() - HTML filelarni o'qish
#
# pd.read_json() - JSON filelarni o'qish
#
# pd.read_pickle() - Pickle filelarni o'qish
#
# pd.read_sql() - SQL Querydan qaytgan filelarni o'qish (SQL Alchemy bilan ishlaydi)

# %%
# !wget = "https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/refs/heads/main/merc.csv"
# Out:
# --2025-04-12 05:58:48--  http://=/
# Resolving = (=)... failed: Name or service not known.
# wget: unable to resolve host address ‘=’
# --2025-04-12 05:58:48--  https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/refs/heads/main/merc.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 728047 (711K) [text/plain]
# Saving to: ‘merc.csv’
#
# merc.csv            100%[===================>] 710.98K  --.-KB/s    in 0.008s
#
# 2025-04-12 05:58:48 (82.6 MB/s) - ‘merc.csv’ saved [728047/728047]
#
# FINISHED --2025-04-12 05:58:48--
# Total wall clock time: 0.1s
# Downloaded: 1 files, 711K in 0.008s (82.6 MB/s)

# %%
# !git clone "https://github.com/anvarnarz/praktikum_datasets"
# Out:
# Cloning into 'praktikum_datasets'...
# remote: Enumerating objects: 145, done.
# remote: Counting objects: 100% (52/52), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 145 (delta 46), reused 44 (delta 43), pack-reused 93 (from 1)
# Receiving objects: 100% (145/145), 9.72 MiB | 12.47 MiB/s, done.
# Resolving deltas: 100% (53/53), done.
